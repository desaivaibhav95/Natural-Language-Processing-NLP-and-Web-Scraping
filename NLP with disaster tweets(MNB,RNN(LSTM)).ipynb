# %%
import pandas as pd
import numpy as np

# %%
train = pd.read_csv("/kaggle/input/nlp-getting-started/train.csv")
test = pd.read_csv("/kaggle/input/nlp-getting-started/test.csv")

# %%
train_id = train['id']
test_id = test['id']

# %%
train.drop(columns = ['id'], inplace = True)
test.drop(columns = ['id'], inplace = True)

# %% [markdown]
# Location column has a lot of missing values and keyword column contains information that is present in the text column and we will be exracting that information down the line from the text column

# %%
train.isnull().sum()
# Out:
# keyword       61
# location    2533
# text           0
# target         0
# dtype: int64

# %%
test.isnull().sum()
# Out:
# keyword       26
# location    1105
# text           0
# dtype: int64

# %%
train.drop(columns = ['keyword','location'], inplace = True)
test.drop(columns = ['keyword','location'], inplace = True)

# %%
train.head()
# Out:
#                                                 text  target
# 0  Our Deeds are the Reason of this #earthquake M...       1
# 1             Forest fire near La Ronge Sask. Canada       1
# 2  All residents asked to 'shelter in place' are ...       1
# 3  13,000 people receive #wildfires evacuation or...       1
# 4  Just got sent this photo from Ruby #Alaska as ...       1

# %% [markdown]
# ## Data Cleaning

# %%
# Converting all text to lowercase
train['text'] = [t.lower() for t in train['text']]
test['text'] = [t.lower() for t in test['text']]

# %%
# Removing punctuations
import re
import string
train['text'] = [re.sub('[%s]' % re.escape(string.punctuation), '', i) for i in train['text']]
test['text'] = [re.sub('[%s]' % re.escape(string.punctuation), '', i) for i in test['text']]

# %%
# Removing numeric characters
train['text'] = [re.sub('\d','',n) for n in train['text']]
test['text'] = [re.sub('\d','',n) for n in test['text']]

# %% [markdown]
# ## Preprocessing Text Data

# %% [markdown]
# ### Tokenization and Stop Words

# %%
import nltk
from nltk.tokenize import word_tokenize

# %%
# Word Tokenization

train['text'] = [word_tokenize(i) for i in train['text']]
test['text'] = [word_tokenize(i) for i in test['text']]

# %%
train['text'].head()
# Out:
# 0    [our, deeds, are, the, reason, of, this, earth...
# 1        [forest, fire, near, la, ronge, sask, canada]
# 2    [all, residents, asked, to, shelter, in, place...
# 3    [people, receive, wildfires, evacuation, order...
# 4    [just, got, sent, this, photo, from, ruby, ala...
# Name: text, dtype: object

# %%
# Stop Words Removal

from nltk.corpus import stopwords

stop_words = set(stopwords.words('english'))
train['text'] = [[i for i in j if not i in stop_words] for j in train['text']]
test['text'] = [[i for i in j if not i in stop_words] for j in test['text']]

# %%
train.head()
# Out:
#                                                 text  target
# 0  [deeds, reason, earthquake, may, allah, forgiv...       1
# 1      [forest, fire, near, la, ronge, sask, canada]       1
# 2  [residents, asked, shelter, place, notified, o...       1
# 3  [people, receive, wildfires, evacuation, order...       1
# 4  [got, sent, photo, ruby, alaska, smoke, wildfi...       1

# %% [markdown]
# ### Lemmatization

# %%
from collections import defaultdict
from nltk.tag import pos_tag
from nltk.corpus import wordnet as wn

tag_map = defaultdict(lambda : wn.NOUN)
tag_map['J'] = wn.ADJ
tag_map['V'] = wn.VERB
tag_map['R'] = wn.ADV

tag_map
# Out:
# defaultdict(<function __main__.<lambda>()>, {'J': 'a', 'V': 'v', 'R': 'r'})

# %%
from nltk.stem import WordNetLemmatizer

lemmatizer = WordNetLemmatizer()

train['text'] = [[lemmatizer.lemmatize(word, tag_map[tag[0]]) for word, tag in pos_tag(i)] for i in train['text']]
test['text'] = [[lemmatizer.lemmatize(word, tag_map[tag[0]]) for word, tag in pos_tag(i)] for i in test['text']]

# %%
train['lemmatized_text'] = train['text'].apply(lambda x : ' '.join(x))
test['lemmatized_text'] = test['text'].apply(lambda x : ' '.join(x))

# %%
train.head()
# Out:
#                                                 text  target  \
# 0  [deed, reason, earthquake, may, allah, forgive...       1
# 1      [forest, fire, near, la, ronge, sask, canada]       1
# 2  [resident, ask, shelter, place, notify, office...       1
# 3  [people, receive, wildfire, evacuation, order,...       1
# 4  [get, sent, photo, ruby, alaska, smoke, wildfi...       1
#
#                                      lemmatized_text
# 0         deed reason earthquake may allah forgive u
# 1              forest fire near la ronge sask canada
# 2  resident ask shelter place notify officer evac...
# 3  people receive wildfire evacuation order calif...
# 4  get sent photo ruby alaska smoke wildfires pou...

# %%
train.drop(columns = ['text'], inplace = True)
test.drop(columns = ['text'], inplace = True)

# %% [markdown]
# ### Word Embedding using TF_IDF Vectorizer

# %%
# Assigning numbers(vectors) to words in our data
from sklearn.feature_extraction.text import TfidfVectorizer
tfidf = TfidfVectorizer(max_features = 5000) 

train_emb = tfidf.fit_transform(train['lemmatized_text']).toarray()
test_emb = tfidf.fit_transform(test['lemmatized_text']).toarray()

# %%
train_emb.shape[1:]
# Out:
# (5000,)

# %%
y = train['target']

# %% [markdown]
# ## Model Training

# %% [markdown]
# ### Multinomial Naive Bayes

# %%
from sklearn.model_selection import train_test_split
from sklearn.naive_bayes import MultinomialNB
from sklearn.metrics import accuracy_score, classification_report, roc_auc_score

# %%
MNB = MultinomialNB()

# %% [markdown]
# Splitting the train set in train and validation set to see how good is Naive Bayes for our data

# %%
x_train,x_valid,y_train,y_valid = train_test_split(train_emb,y,test_size = 0.3, random_state = 100)

# %%
MNB.fit(x_train,y_train)
pred_MNB = MNB.predict(x_valid)

# %%
print("Accuracy score : {:.2f}".format(accuracy_score(y_valid, pred_MNB)))
# Out:
# Accuracy score : 0.81

# %%
print("ROC-AUC score : {:.2f}".format(roc_auc_score(y_valid, pred_MNB)))
# Out:
# ROC-AUC score : 0.79

# %%
print(classification_report(y_valid, pred_MNB))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.79      0.91      0.84      1322
#            1       0.84      0.67      0.74       962
#
#     accuracy                           0.81      2284
#    macro avg       0.81      0.79      0.79      2284
# weighted avg       0.81      0.81      0.80      2284

# %% [markdown]
# ### Model Training

# %%
MNB.fit(train_emb,y)
# Out:
# MultinomialNB()

# %%
MNB_predictions = MNB.predict(test_emb)

# %%
Prediction_results = pd.DataFrame({"target": MNB_predictions}, index = test_id)

# %%
#submission_file = Prediction_results.to_csv('submission.csv')

# %% [markdown]
# #### Multinomial Naive Bayes got a 0.515 score which is decent but can be significantly improved.

# %% [markdown]
# ### Support Vector Machines

# %%
from sklearn import svm
SVC = svm.SVC()
#SVC.fit(x_train,y_train)
#pred_SVC = SVC.predict(x_valid)

# %%
#print("Accuracy score : {:.2f}".format(accuracy_score(y_valid, pred_SVC)))

# %%
#print("ROC-AUC score : {:.2f}".format(roc_auc_score(y_valid, pred_SVC)))

# %% [markdown]
# ## Alternative Approach using Sequencing, Padding, and using RNN(LSTM)

# %% [markdown]
# ### Sequencing and Sentence Padding

# %%
from collections import Counter

# Finding the number of unique word in the corpus
def word_counter(text):
    count = Counter()
    for i in text.values:
        for word in i.split():
            count[word] += 1
    return count

# %%
train.head()
# Out:
#    target                                    lemmatized_text
# 0       1         deed reason earthquake may allah forgive u
# 1       1              forest fire near la ronge sask canada
# 2       1  resident ask shelter place notify officer evac...
# 3       1  people receive wildfire evacuation order calif...
# 4       1  get sent photo ruby alaska smoke wildfires pou...

# %%
train_text = train.lemmatized_text
counter = word_counter(train_text)
counter
# Out:
# Counter({'deed': 2,
#          'reason': 31,
#          'earthquake': 51,
#          'may': 88,
#          'allah': 9,
#          'forgive': 4,
#          'u': 254,
#          'forest': 66,
#          'fire': 357,
#          'near': 55,
#          'la': 29,
#          'ronge': 1,
#          'sask': 1,
#          'canada': 13,
#          'resident': 8,
#          'ask': 28,
#          'shelter': 6,
#          'place': 35,
#          'notify': 1,
#          'officer': 37,
#          'evacuation': 52,
#          'order': 38,
#          'expect': 32,
#          'people': 199,
#          'receive': 3,
#          'wildfire': 81,
#          'california': 119,
#          'get': 435,
#          'sent': 5,
#          'photo': 65,
#          'ruby': 1,
#          'alaska': 7,
#          'smoke': 53,
#          'wildfires': 2,
#          'pour': 4,
#          'school': 70,
#          'rockyfire': 4,
#          'update': 53,
#          'hwy': 10,
#          'close': 32,
#          'direction': 15,
#          'due': 31,
#          'lake': 15,
#          'county': 38,
#          'cafire': 2,
#          'flood': 155,
#          'disaster': 156,
#          'heavy': 20,
#          'rain': 58,
#          'cause': 104,
#          'flash': 21,
#          'street': 32,
#          'manitou': 1,
#          'colorado': 16,
#          'spring': 18,
#          'area': 48,
#          'im': 299,
#          'top': 57,
#          'hill': 12,
#          'see': 149,
#          'wood': 6,
#          'there': 32,
#          'emergency': 158,
#          'happen': 48,
#          'building': 129,
#          'across': 20,
#          'afraid': 5,
#          'tornado': 36,
#          'come': 158,
#          'three': 29,
#          'die': 69,
#          'heat': 46,
#          'wave': 73,
#          'far': 29,
#          'haha': 20,
#          'south': 27,
#          'tampa': 4,
#          'hah': 3,
#          'wait': 39,
#          'second': 35,
#          'live': 89,
#          'gon': 47,
#          'na': 79,
#          'fvck': 1,
#          'flooding': 12,
#          'florida': 6,
#          'tampabay': 1,
#          'day': 142,
#          'ive': 43,
#          'lose': 39,
#          'count': 3,
#          'bago': 2,
#          'myanmar': 19,
#          'arrive': 18,
#          'damage': 71,
#          'bus': 48,
#          'multi': 2,
#          'car': 112,
#          'crash': 158,
#          'breaking': 1,
#          'whats': 29,
#          'man': 111,
#          'love': 123,
#          'fruit': 8,
#          'summer': 43,
#          'lovely': 8,
#          'fast': 23,
#          'goooooooaaaaaal': 1,
#          'ridiculous': 4,
#          'london': 16,
#          'cool': 34,
#          'skiing': 1,
#          'wonderful': 5,
#          'looooool': 1,
#          'wayi': 1,
#          'cant': 102,
#          'eat': 10,
#          'shit': 56,
#          'nyc': 12,
#          'last': 86,
#          'week': 43,
#          'girlfriend': 6,
#          'cooool': 1,
#          'like': 391,
#          'pasta': 2,
#          'end': 58,
#          'bbcmtd': 1,
#          'wholesale': 4,
#          'market': 39,
#          'ablaze': 28,
#          'httptcolhyxeohyc': 1,
#          'always': 46,
#          'try': 61,
#          'bring': 36,
#          'metal': 13,
#          'rt': 107,
#          'httptcoyaoexngw': 1,
#          'africanbaze': 1,
#          'break': 73,
#          'newsnigeria': 1,
#          'flag': 25,
#          'set': 63,
#          'aba': 14,
#          'httptconndbgwyei': 1,
#          'cry': 20,
#          'plus': 8,
#          'side': 29,
#          'look': 144,
#          'sky': 20,
#          'night': 52,
#          'httptcoqqsmshajn': 1,
#          'phdsquares': 1,
#          'mufc': 2,
#          'theyve': 5,
#          'build': 29,
#          'much': 64,
#          'hype': 4,
#          'around': 39,
#          'new': 230,
#          'acquisition': 2,
#          'doubt': 5,
#          'epl': 1,
#          'season': 17,
#          'inec': 2,
#          'office': 14,
#          'abia': 2,
#          'httptcoimaomknna': 1,
#          'barbados': 1,
#          'bridgetown': 1,
#          'jamaica': 5,
#          '\x89ûò': 40,
#          'two': 97,
#          'santa': 6,
#          'cruz': 10,
#          '\x89ûó': 26,
#          'head': 59,
#          'st': 46,
#          'elizabeth': 2,
#          'police': 140,
#          'superintende': 1,
#          'httptcowdueajqj': 1,
#          'lord': 20,
#          'check': 50,
#          'httptcoroinsmejj': 2,
#          'httptcotjzjin': 2,
#          'httptcoyduixefipe': 2,
#          'httptcolxtjckls': 2,
#          'nsfw': 3,
#          'outside': 25,
#          'youre': 67,
#          'alive': 11,
#          'dead': 96,
#          'inside': 29,
#          'awesome': 16,
#          'time': 176,
#          'visit': 12,
#          'cfc': 2,
#          'ancop': 1,
#          'site': 30,
#          'thanks': 30,
#          'tita': 1,
#          'vida': 2,
#          'take': 137,
#          'care': 33,
#          'soooo': 2,
#          'pump': 6,
#          'southridgelife': 1,
#          'want': 116,
#          'chicago': 12,
#          'preach': 1,
#          'hotel': 6,
#          'httptcooqknbfofx': 1,
#          'gain': 12,
#          'follower': 10,
#          'know': 133,
#          'stats': 3,
#          'grow': 21,
#          'httptcotiyulifc': 1,
#          'west': 24,
#          'burn': 152,
#          'thousand': 23,
#          'alone': 19,
#          'httptcovltbrwbr': 1,
#          'perfect': 10,
#          'tracklist': 1,
#          'life': 110,
#          'leave': 71,
#          'first': 107,
#          'retainer': 1,
#          'quite': 10,
#          'weird': 9,
#          'good': 100,
#          'use': 77,
#          'wear': 9,
#          'every': 59,
#          'single': 14,
#          'next': 50,
#          'year': 150,
#          'least': 36,
#          'deputy': 6,
#          'shoot': 36,
#          'brighton': 2,
#          'home': 138,
#          'httptcogwnrhmsok': 1,
#          'wife': 12,
#          'six': 4,
#          'jail': 5,
#          'niece': 4,
#          'httptcoevahoucza': 1,
#          'superintendent': 1,
#          'lanford': 1,
#          'salmon': 3,
#          'r': 23,
#          'httptcovplrhkau': 1,
#          'httptcosxhwtnnlf': 1,
#          'arsonist': 19,
#          'deliberately': 1,
#          'black': 67,
#          'church': 9,
#          'north': 27,
#          'carolinaåêablaze': 1,
#          'httptcopcxarbhan': 1,
#          'noches': 1,
#          'elbestia': 1,
#          'alexissanchez': 1,
#          'happy': 23,
#          'teammate': 1,
#          'train': 118,
#          'hard': 20,
#          'goodnight': 1,
#          'gunner': 1,
#          'httptcoucjjhvgr': 1,
#          'kurd': 3,
#          'trample': 1,
#          'turkmen': 2,
#          'later': 11,
#          'others': 21,
#          'vandalized': 1,
#          'front': 18,
#          'diyala': 1,
#          'httptcoizfdyccg': 1,
#          'truck': 55,
#          'voortrekker': 1,
#          'ave': 15,
#          'tambo': 1,
#          'intl': 1,
#          'cargo': 3,
#          'section': 5,
#          'httptcokscqkfkkf': 1,
#          'heart': 39,
#          'city': 66,
#          'gift': 5,
#          'skyline': 2,
#          'kiss': 7,
#          'upon': 16,
#          'lip': 5,
#          '\x89û': 65,
#          'httpstcocyompzaz': 1,
#          'tonight': 41,
#          'los': 4,
#          'angeles': 4,
#          'ig': 5,
#          'fb': 4,
#          'fill': 8,
#          'sunset': 7,
#          'shot': 37,
#          'peep': 3,
#          'httptcoicsjgzte': 1,
#          'climate': 19,
#          'energy': 7,
#          'httptcofxmnlbd': 1,
#          'revel': 1,
#          'wmv': 2,
#          'video': 172,
#          'mean': 33,
#          'mac': 7,
#          'farewell': 1,
#          'en': 3,
#          'route': 10,
#          'dvd': 6,
#          'gtxrwm': 1,
#          'progressive': 2,
#          'greeting': 1,
#          'month': 26,
#          'student': 18,
#          'would': 131,
#          'pen': 1,
#          'torch': 6,
#          'publication': 1,
#          'httptcofxpixqujt': 1,
#          'rene': 2,
#          'amp': 300,
#          'jacinta': 1,
#          'secret': 24,
#          'k': 24,
#          'fall': 71,
#          'edit': 2,
#          'mar': 1,
#          'httpstcomlmsuzvz': 1,
#          'navista': 1,
#          'steve': 8,
#          'something': 32,
#          'else': 18,
#          'tinderbox': 1,
#          'clown': 2,
#          'hood': 2,
#          'news': 197,
#          'nowplaying': 26,
#          'ian': 4,
#          'buff': 2,
#          'magnitude': 1,
#          'httptcoavjsjfftc': 1,
#          'edm': 11,
#          'nxwestmidlands': 1,
#          'huge': 21,
#          'httptcorwzbfvnxer': 1,
#          'talk': 33,
#          'go': 275,
#          'dont': 191,
#          'make': 170,
#          'work': 100,
#          'kid': 39,
#          'cuz': 6,
#          'bicycle': 4,
#          'accident': 95,
#          'split': 3,
#          'testicle': 1,
#          'impossible': 4,
#          'michael': 12,
#          'father': 7,
#          'w': 62,
#          'nashvilletraffic': 1,
#          'traffic': 31,
#          'move': 47,
#          'slow': 8,
#          'usual': 5,
#          'httpstcoghkegj': 1,
#          'center': 25,
#          'lane': 13,
#          'block': 29,
#          'santaclara': 1,
#          'nb': 5,
#          'great': 68,
#          'america': 21,
#          'pkwy': 2,
#          'bayarea': 1,
#          'httptcopmlohzurwr': 1,
#          'httptcogkyegjtk': 1,
#          'personalinjury': 1,
#          'read': 67,
#          'advice': 2,
#          'solicitor': 2,
#          'help': 87,
#          'otleyhour': 1,
#          'stlouis': 1,
#          'caraccidentlawyer': 1,
#          'speed': 5,
#          'among': 11,
#          'teen': 15,
#          'httpstcokzomof': 1,
#          'httpstcoskxvmcba': 1,
#          'tee\x89û': 1,
#          'report': 75,
#          'motor': 6,
#          'vehicle': 24,
#          'curry': 1,
#          'herman': 1,
#          'rd': 30,
#          'stephenson': 1,
#          'involve': 17,
#          'overturn': 3,
#          'please': 70,
#          'httptcoybjezkurw': 1,
#          'bigrigradio': 1,
#          'awareness': 2,
#          'mile': 15,
#          'marker': 3,
#          'mooresville': 2,
#          'iredell': 2,
#          'ramp': 1,
#          'pm': 105,
#          'sleepjunkies': 1,
#          'sleep': 18,
#          'pill': 3,
#          'double': 13,
#          'risk': 18,
#          'httptcosnmfict': 1,
#          'httpstcoysxunvceh': 1,
#          'n': 30,
#          'cabrillo': 1,
#          'hwymagellan': 1,
#          'av': 5,
#          'mir': 1,
#          'congestion': 1,
#          'pastor': 1,
#          'scene': 17,
#          'accidentwho': 1,
#          'owner': 16,
#          'range': 4,
#          'rover': 2,
#          'mom': 23,
#          'didnt': 31,
#          'wished': 1,
#          'spilt': 1,
#          'mayonnaise': 1,
#          'horrible': 35,
#          'past': 35,
#          'sunday': 12,
#          'finally': 23,
#          'able': 10,
#          'thank': 33,
#          'god': 64,
#          'piss': 3,
#          'donnie': 1,
#          'tell': 46,
#          'another': 69,
#          'truckcrash': 1,
#          'fortworth': 1,
#          'interstate': 2,
#          'httptcorsljqfp': 1,
#          'click': 7,
#          'youve': 7,
#          'crashgthttptcolduniywk': 1,
#          'ashville': 1,
#          'sb': 4,
#          'sr': 5,
#          'httptcohylmowgfi': 1,
#          'carolina': 1,
#          'motorcyclist': 9,
#          'cross': 57,
#          'median': 1,
#          'motorcycle': 6,
#          'rider': 7,
#          'travel': 18,
#          'httptcoplzrlmy': 1,
#          'fyi': 3,
#          'cadfyi': 2,
#          'property': 18,
#          'damagenhs': 1,
#          'piner': 2,
#          'rdhorndale': 2,
#          'dr': 13,
#          'naayf': 1,
#          'turn': 39,
#          'onto': 8,
#          'chandanee': 1,
#          'magu': 1,
#          'mma': 6,
#          'taxi': 2,
#          'ram': 4,
#          'halfway': 1,
#          'everyone': 53,
#          'conf\x89û': 1,
#          'manchester': 9,
#          'eddy': 1,
#          'stop': 66,
#          'back': 122,
#          'nha': 1,
#          'delay': 10,
#          'min': 9,
#          'httptcooiafxigm': 1,
#          'damagewpd': 1,
#          'th': 50,
#          'injury': 80,
#          'willis': 1,
#          'foreman': 1,
#          'httptcovckitedev': 1,
#          'aashiqui': 1,
#          'actress': 2,
#          'anu': 1,
#          'aggarwal': 1,
#          'nearfatal': 1,
#          'httptcootfplqw': 1,
#          'suffield': 1,
#          'alberta': 4,
#          'httpstcobptmlfp': 1,
#          'backup': 3,
#          'southaccident': 1,
#          'right': 73,
#          'exit': 9,
#          'langtree': 1,
#          'rdconsider': 1,
#          'nc': 10,
#          'alternate': 1,
#          'change': 61,
#          'determine': 2,
#          'option': 9,
#          'financially': 1,
#          'support': 28,
#          'plan': 91,
#          'ongoing': 1,
#          'treatment': 7,
#          'deadly': 11,
#          'hagerstown': 1,
#          'today': 97,
#          'ill': 38,
#          'detail': 6,
#          'yourstate': 1,
#          'whag': 1,
#          'flowri': 1,
#          'marinade': 1,
#          'even': 83,
#          'fucking': 9,
#          'mf': 5,
#          'fuck': 80,
#          'drive': 43,
#          'norwaymfa': 1,
#          'bahrain': 1,
#          'previously': 4,
#          'road': 46,
#          'kill': 173,
#          'explosion': 42,
#          'httpstcogfjfgtodad': 1,
#          'still': 129,
#          'hear': 33,
#          'leader': 12,
#          'kenya': 4,
#          'forward': 4,
#          'comment': 19,
#          'issue': 59,
#          'disciplinary': 1,
#          'measuresarrestpastornganga': 1,
#          'aftershockdelo': 2,
#          'scuf': 2,
#          'ps': 1,
#          'game': 50,
#          'cya': 1,
#          'effort': 11,
#          'painful': 1,
#          'win': 29,
#          'roger': 2,
#          'bannister': 1,
#          'ir': 7,
#          'icemoon': 7,
#          'aftershock': 20,
#          'httptcoynxnvvkcda': 1,
#          'djicemoon': 7,
#          'dubstep': 8,
#          'trapmusic': 7,
#          'dnb': 8,
#          'dance': 16,
#          'ices\x89û': 7,
#          'httptcoweqpesenku': 1,
#          'victory': 5,
#          'bargain': 5,
#          'basement': 3,
#          'price': 12,
#          'dwight': 1,
#          'david': 8,
#          'eisenhower': 1,
#          'httptcovampodgyw': 2,
#          'httptcozevakjapcz': 2,
#          'nobody': 5,
#          'remembers': 1,
#          'charles': 4,
#          'schulz': 1,
#          'speak': 8,
#          'someone': 44,
#          'xb': 2,
#          'p': 26,
#          'also': 44,
#          'harder': 1,
#          'conflict': 6,
#          'glorious': 3,
#          'triumph': 2,
#          'thomas': 7,
#          'paine': 1,
#          'growingupspoiled': 1,
#          'clay': 1,
#          'pigeon': 1,
#          'guess': 16,
#          'one': 205,
#          'actually': 28,
#          'free': 44,
#          'tc': 2,
#          'terrify': 4,
#          'best': 74,
#          'roller': 3,
#          'coaster': 2,
#          'ever': 54,
#          'disclaimer': 1,
#          'httpstcoxmwodfmtui': 1,
#          'httptcomjdzmgjow': 1,
#          'httptconuhasfkbv': 1,
#          'httptcoeepzhoth': 1,
#          'httptcoaddoq': 1,
#          'kjfordays': 1,
#          'httptcothyzomvwu': 2,
#          'httptcojooxk': 2,
#          'wisdomwed': 1,
#          'bonus': 1,
#          'minute': 42,
#          'daily': 21,
#          'habit': 3,
#          'could': 81,
#          'really': 71,
#          'improve': 3,
#          'many': 84,
#          'already': 29,
#          'lifehack': 1,
#          'httptcotbmfqbcw': 1,
#          'protect': 9,
#          'profit': 4,
#          'global': 18,
#          'financial': 13,
#          'meltdown': 32,
#          'wiedemer': 1,
#          'http': 1,
#          'httptcowztzhgmvq': 1,
#          'moment': 24,
#          'scary': 9,
#          'guy': 46,
#          'behind': 17,
#          'scream': 105,
#          'bloody': 44,
#          'murder': 50,
#          'silverwood': 1,
#          '\x89ã¢': 1,
#          'full\x89ã¢': 1,
#          'stream': 10,
#          'youtube': 98,
#          'httptcovveusesgf': 1,
#          'gtgt': 13,
#          'book': 33,
#          'httptcofntucz': 1,
#          'esquireattire': 1,
#          'sometimes': 13,
#          'face': 53,
#          'difficulty': 2,
#          'wrong': 21,
#          'joel': 3,
#          'osteen': 1,
#          'thing': 72,
#          'stand': 28,
#          'dream': 15,
#          'belief': 4,
#          'possible': 32,
#          'brown': 26,
#          'praise': 1,
#          'ministry': 1,
#          'wdyouth': 1,
#          'biblestudy': 1,
#          'httpstcoujkegbcc': 1,
#          'remember': 38,
#          'way': 85,
#          'avoid': 20,
#          'trap': 46,
#          'think': 124,
#          'job': 47,
#          'tried': 3,
#          'orange': 4,
#          'never': 61,
#          'onfireanders': 1,
#          'bb': 7,
#          'httpstcojvppkhjy': 1,
#          'kick': 16,
#          'say': 199,
#          'do': 29,
#          'interrupt': 1,
#          'george': 6,
#          'bernard': 1,
#          'shaw': 2,
#          'oyster': 1,
#          'shell': 5,
#          'andrew': 2,
#          'carnegie': 1,
#          'anyone': 24,
#          'need': 101,
#          'pu': 1,
#          'play': 58,
#          'hybrid': 3,
#          'slayer': 3,
#          'eu': 3,
#          'hmu': 2,
#          'codsandscrims': 1,
#          'empirikgaming': 1,
#          'codawscrims': 1,
#          'tpkotc': 1,
#          'tpfa': 1,
#          'aftershockorg': 1,
#          'expert': 22,
#          'france': 16,
#          'begin': 34,
#          'examine': 10,
#          'airplane': 36,
#          'debris': 50,
#          'find': 82,
#          'reunion': 33,
#          'island': 40,
#          'french': 10,
#          'air': 42,
#          'httptcoyvvpznzmxg': 1,
#          'strict': 2,
#          'liability': 2,
#          'context': 3,
#          'pilot': 14,
#          'error': 5,
#          'common': 11,
#          'component': 2,
#          'aviation': 2,
#          'cr': 4,
#          'httptcoczbohrd': 1,
#          'crobscarla': 1,
#          'lifetime': 3,
#          'odds': 3,
#          'wedn': 2,
#          'httptcobkpfpogysi': 1,
#          'alexalltimelow': 1,
#          'awwww': 2,
#          'theyre': 23,
#          'cuties': 1,
#          'family': 132,
#          'member': 19,
#          'osama': 1,
#          'bin': 10,
#          'laden': 9,
#          'ironic': 2,
#          'mhmmm': 1,
#          'gov': 9,
#          'suspect': 44,
#          'engine': 5,
#          'httptcotyjxrfdst': 1,
#          'via': 220,
#          'wing': 9,
#          'httptcoikztevbv': 1,
#          'cessna': 1,
#          'ocampo': 1,
#          'coahuila': 2,
#          'mexico': 7,
#          'july': 7,
#          'four': 17,
#          'men': 30,
#          'include': 15,
#          'state': 60,
#          'government': 33,
#          'official': 51,
#          'watchthevideo': 1,
#          'httptcopxrvgjik': 1,
#          'httptcolsmxvwrj': 1,
#          'wednesday\x89û': 1,
#          'wednesday': 16,
#          'kca': 4,
#          'votejktid': 4,
#          'mbataweel': 1,
#          'rip': 13,
#          'binladen': 1,
#          'almost': 25,
#          'send': 46,
#          'coworker': 2,
#          'nude': 4,
#          'mode': 16,
#          'mickinyman': 1,
#          'theatlantic': 1,
#          'might': 23,
#          'wreck': 95,
#          'politics': 5,
#          'httptcotagzbcxfj': 1,
#          'mlb': 5,
#          'unbelievably': 1,
#          'insane': 6,
#          'airport': 31,
#          'aircraft': 25,
#          'aeroplane': 1,
#          'runway': 7,
#          'freaky\x89û': 1,
#          'httpstcocezhqczll': 1,
#          'airplaneåê': 1,
#          'httptcowqwjsgphl': 1,
#          'httptcotfcdronra': 1,
#          'usama': 1,
#          'ladin': 1,
#          'naturally': 1,
#          'dy': 4,
#          'plane': 35,
#          'festival': 6,
#          'httpstcokqaeapb': 1,
#          'death': 108,
#          'carfest': 1,
#          'httptcogibyqhhkpk': 1,
#          'dtn': 4,
#          'brazil': 7,
#          'exp': 6,
#          'httptcomigwqlq': 1,
#          'httptcovsmaeslk': 1,
#          '\x89ûïairplane\x89û\x9d': 1,
#          'wtf': 12,
#          'can\x89ûªt': 6,
#          'believe': 29,
#          'eye': 41,
#          'httptcoffylajwps': 1,
#          'nicole': 1,
#          'fletcher': 1,
#          'victim': 27,
#          'ago': 26,
#          'little': 48,
#          'bit': 13,
#          'trauma': 39,
#          'although': 3,
#          'shes': 22,
#          'omg': 21,
#          'httptcoxdxdprcpns': 1,
#          'bro': 8,
#          'jetengine': 1,
#          'turbojet': 1,
#          'boing': 1,
#          'g': 16,
#          'httptcokxxnszpnk': 1,
#          'phone': 41,
#          'ship': 38,
#          'terrible': 7,
#          'statistically': 1,
#          'cop': 21,
#          'house': 65,
#          'colombia': 1,
#          'httpstcozhjlflbhzl': 1,
#          'httpstcoieccjdoub': 1,
#          'drone': 11,
#          'worry': 20,
#          'esp': 3,
#          'vicinity': 2,
#          'httptcokzrgngjf': 1,
#          'early': 19,
#          'wake': 36,
#          'call': 77,
#          'sister': 11,
#          'beg': 2,
#          'ride': 4,
#          'wher': 1,
#          'ambulance': 41,
#          'hospital': 12,
#          'rodkiai': 1,
#          'httptcoayzzcupnz': 1,
#          'twelve': 14,
#          'fear': 90,
#          'pakistani': 16,
#          'helicopter': 27,
#          'httptcoscdnsmc': 1,
#          'serious': 13,
#          'lorry': 6,
#          'httptcopfeaqeski': 1,
#          'httptcofntgrnkx': 1,
#          'emsne\x89û': 1,
#          'reuters': 24,
#          'httptcomdnugvubwn': 1,
#          'yugvani': 3,
#          'lead': 45,
#          'service': 82,
#          'boss': 1,
#          'welcome': 10,
#          'charity': 8,
#          'httptcomjjqpsv': 1,
#          'aberystwythshrewsbury': 1,
#          'incident': 11,
#          'halt': 2,
#          'shrews': 1,
#          'httptcoxumylcbq': 1,
#          'sprinter': 4,
#          'automatic': 7,
#          'frontline': 4,
#          'choice': 10,
#          'lez': 4,
#          'compliant': 4,
#          'ebay': 33,
#          'httptcoevttqpeia': 1,
#          'nanotech': 1,
#          'device': 3,
#          'target': 19,
#          'destroy': 88,
#          'blood': 42,
#          'clot': 1,
#          'httptcohfyvslbb': 1,
#          'skyhawkmm': 1,
#          'traplord': 1,
#          'fredosantana': 1,
#          'lilreese': 1,
#          'hella': 2,
#          'crazy': 22,
#          'fight': 42,
#          'couple': 23,
#          'mosh': 1,
#          'pit': 4,
#          'run': 75,
#          'lucky': 11,
#          'justsaying': 1,
#          'randomthought': 1,
#          'httptcobfestwbzt': 1,
#          'tilnow': 3,
#          'dna': 1,
#          'httptcoxglahzl': 1,
#          'httptcothmblaatzp': 1,
#          'tanslash': 1,
#          'fouseytube': 2,
#          'ok': 36,
#          'hahahah': 2,
#          'httptcozsberqnnn': 1,
#          'httptcoqivrzojzv': 1,
#          'pakistan': 22,
#          'nine': 6,
#          'httptcoeryebmf': 1,
#          'thenissonian': 1,
#          'rejectdcartoons': 1,
#          'nissan': 1,
#          'medical': 6,
#          'assistance': 4,
#          'em': 14,
#          'ny': 10,
#          'emts': 1,
#          'petition': 12,
#          'per': 3,
#          'hour': 42,
#          '\x89û÷minimum': 1,
#          'wage\x89ûª': 1,
#          'httptcooaswlxmr': 1,
#          'ems': 2,
#          'paramedic': 4,
#          'httptcofcqmkffflw': 1,
#          'httptcovayaymbngu': 1,
#          'httptcobrmesnt': 1,
#          'httptcoujrxkgawp': 1,
#          'httptcokplfaute': 1,
#          'kiwikaryn': 1,
#          'park': 19,
#          'lot': 41,
#          'john': 7,
#          'httptcohpvodudip': 1,
#          'ltlt': 2,
#          'killed': 1,
#          'httptcoshzpyiqok': 1,
#          'httptcopwwpumrbj': 1,
#          'httptcoyspondqo': 1,
#          '\x89ûïleoblakecarter': 1,
#          'dog': 29,
#          'he': 41,
#          'httptcomglpgrrm\x89û\x9dnatasharideout': 1,
#          'hatzolah': 1,
#          'respond': 16,
#          'dual': 3,
#          'siren': 51,
#          'and\x89û': 2,
#          'httpstcosekmqnjf': 1,
#          'httptcofuerkgwui': 1,
#          'httptcomvggglmvc': 1,
#          'httptcoxyeuyltx': 1,
#          'httptcougrmdzn': 1,
#          'httptcothywbbeet': 1,
#          'worldnews': 9,
#          'httptcoxqsjodu': 1,
#          'number': 19,
#          'lesotho': 1,
#          'body': 151,
#          'medic': 3,
#          'aaceorg': 1,
#          'surprise': 11,
#          'standardise': 1,
#          'clinical': 1,
#          'practice': 10,
#          'nh': 3,
#          'trust': 20,
#          'httptcojtytxrrk': 1,
#          'httptcodnazoi': 1,
#          ...})

# %%
print("Number of unique words in the corpus : {:.2f}".format(len(counter)))
# Out:
# Number of unique words in the corpus : 19694.00

# %%
words = len(counter)
# maximum number of words in a sequence
max_length = 20

# %%
train_sent = train['lemmatized_text']
train_labels = train['target']
test_sent = test['lemmatized_text']

# %%
from keras.preprocessing.text import Tokenizer

tokenizer = Tokenizer(num_words=words)
tokenizer.fit_on_texts(train_sent)
# Out:
# Using TensorFlow backend.

# %%
word_index = tokenizer.word_index
word_index
# Out:
# {'get': 1,
#  'like': 2,
#  'fire': 3,
#  'amp': 4,
#  'im': 5,
#  'go': 6,
#  'u': 7,
#  'new': 8,
#  'via': 9,
#  'one': 10,
#  'people': 11,
#  'say': 12,
#  'news': 13,
#  'bomb': 14,
#  'dont': 15,
#  'time': 16,
#  'kill': 17,
#  'video': 18,
#  'make': 19,
#  'emergency': 20,
#  'come': 21,
#  'crash': 22,
#  'disaster': 23,
#  'flood': 24,
#  'burn': 25,
#  'body': 26,
#  'year': 27,
#  'see': 28,
#  'attack': 29,
#  'look': 30,
#  'day': 31,
#  'police': 32,
#  'home': 33,
#  'take': 34,
#  'know': 35,
#  'family': 36,
#  'would': 37,
#  'building': 38,
#  'still': 39,
#  'storm': 40,
#  'think': 41,
#  'love': 42,
#  'back': 43,
#  'california': 44,
#  'watch': 45,
#  'train': 46,
#  'suicide': 47,
#  'want': 48,
#  'world': 49,
#  'car': 50,
#  'man': 51,
#  'life': 52,
#  'collapse': 53,
#  'bag': 54,
#  'death': 55,
#  'rt': 56,
#  'first': 57,
#  'pm': 58,
#  'scream': 59,
#  'cause': 60,
#  'cant': 61,
#  'need': 62,
#  'nuclear': 63,
#  'good': 64,
#  'work': 65,
#  'war': 66,
#  'youtube': 67,
#  'two': 68,
#  'today': 69,
#  'dead': 70,
#  'let': 71,
#  'accident': 72,
#  'wreck': 73,
#  'plan': 74,
#  'full': 75,
#  'hiroshima': 76,
#  'fear': 77,
#  'live': 78,
#  'drown': 79,
#  'may': 80,
#  'destroy': 81,
#  'weapon': 82,
#  'help': 83,
#  'last': 84,
#  'way': 85,
#  'many': 86,
#  'even': 87,
#  'find': 88,
#  'service': 89,
#  'feel': 90,
#  'woman': 91,
#  'wildfire': 92,
#  'could': 93,
#  'injury': 94,
#  'fuck': 95,
#  'survive': 96,
#  'big': 97,
#  'na': 98,
#  'wound': 99,
#  'rescue': 100,
#  'use': 101,
#  'call': 102,
#  'explode': 103,
#  'evacuate': 104,
#  'report': 105,
#  'run': 106,
#  'save': 107,
#  'bad': 108,
#  'collide': 109,
#  'best': 110,
#  'wave': 111,
#  'break': 112,
#  'right': 113,
#  'mh': 114,
#  'thing': 115,
#  'well': 116,
#  'mass': 117,
#  'panic': 118,
#  'damage': 119,
#  'leave': 120,
#  'fall': 121,
#  'really': 122,
#  'army': 123,
#  'quarantine': 124,
#  'school': 125,
#  'please': 126,
#  'lol': 127,
#  'late': 128,
#  'die': 129,
#  'another': 130,
#  'great': 131,
#  'miss': 132,
#  'fatality': 133,
#  'youre': 134,
#  'black': 135,
#  'read': 136,
#  'hot': 137,
#  'crush': 138,
#  'derail': 139,
#  'forest': 140,
#  'city': 141,
#  'stop': 142,
#  'riot': 143,
#  'photo': 144,
#  '\x89û': 145,
#  'house': 146,
#  'hostage': 147,
#  'fatal': 148,
#  'much': 149,
#  'god': 150,
#  'northern': 151,
#  'old': 152,
#  'water': 153,
#  'detonate': 154,
#  'set': 155,
#  'hit': 156,
#  'w': 157,
#  'obama': 158,
#  'deluge': 159,
#  'bomber': 160,
#  'try': 161,
#  'change': 162,
#  'never': 163,
#  'state': 164,
#  'release': 165,
#  'confirm': 166,
#  'casualty': 167,
#  'head': 168,
#  'every': 169,
#  'issue': 170,
#  'start': 171,
#  'hijack': 172,
#  'rain': 173,
#  'end': 174,
#  'play': 175,
#  'show': 176,
#  'japan': 177,
#  'atomic': 178,
#  'electrocute': 179,
#  'obliterate': 180,
#  'top': 181,
#  'cross': 182,
#  'thats': 183,
#  'flame': 184,
#  'demolish': 185,
#  'shit': 186,
#  'give': 187,
#  'keep': 188,
#  'wind': 189,
#  'near': 190,
#  'truck': 191,
#  'oil': 192,
#  'thunderstorm': 193,
#  'ever': 194,
#  'hope': 195,
#  'post': 196,
#  'land': 197,
#  'content': 198,
#  'smoke': 199,
#  'update': 200,
#  'everyone': 201,
#  'face': 202,
#  'movie': 203,
#  'charge': 204,
#  'evacuation': 205,
#  'night': 206,
#  'since': 207,
#  'sign': 208,
#  'girl': 209,
#  'pick': 210,
#  'military': 211,
#  'earthquake': 212,
#  'official': 213,
#  'siren': 214,
#  'weather': 215,
#  'without': 216,
#  'check': 217,
#  'next': 218,
#  'th': 219,
#  'game': 220,
#  'murder': 221,
#  'debris': 222,
#  'high': 223,
#  'story': 224,
#  'malaysia': 225,
#  'boy': 226,
#  'sound': 227,
#  'area': 228,
#  'happen': 229,
#  'bus': 230,
#  'little': 231,
#  'child': 232,
#  'warn': 233,
#  'gon': 234,
#  'move': 235,
#  'job': 236,
#  'food': 237,
#  'blaze': 238,
#  'severe': 239,
#  'heat': 240,
#  'always': 241,
#  'st': 242,
#  'tell': 243,
#  'road': 244,
#  'guy': 245,
#  'trap': 246,
#  'send': 247,
#  'wild': 248,
#  'terrorist': 249,
#  'migrant': 250,
#  'thunder': 251,
#  'reddit': 252,
#  'lead': 253,
#  'fan': 254,
#  'blow': 255,
#  'natural': 256,
#  'ruin': 257,
#  'spill': 258,
#  'loud': 259,
#  'someone': 260,
#  'also': 261,
#  'free': 262,
#  'bloody': 263,
#  'suspect': 264,
#  'lightning': 265,
#  'ive': 266,
#  'summer': 267,
#  'week': 268,
#  'drive': 269,
#  'light': 270,
#  'put': 271,
#  'explosion': 272,
#  'minute': 273,
#  'air': 274,
#  'blood': 275,
#  'fight': 276,
#  'hour': 277,
#  'battle': 278,
#  'outbreak': 279,
#  'sink': 280,
#  'baby': 281,
#  'bridge': 282,
#  'failure': 283,
#  'tonight': 284,
#  'eye': 285,
#  'phone': 286,
#  'ambulance': 287,
#  'lot': 288,
#  'he': 289,
#  'whole': 290,
#  'survivor': 291,
#  'hail': 292,
#  'business': 293,
#  'hurricane': 294,
#  'affect': 295,
#  'derailment': 296,
#  'wreckage': 297,
#  '\x89ûò': 298,
#  'island': 299,
#  'follow': 300,
#  'saudi': 301,
#  'rise': 302,
#  'sinkhole': 303,
#  'wait': 304,
#  'lose': 305,
#  'market': 306,
#  'around': 307,
#  'heart': 308,
#  'kid': 309,
#  'turn': 310,
#  'trauma': 311,
#  'destruction': 312,
#  'part': 313,
#  'word': 314,
#  'harm': 315,
#  'landslide': 316,
#  'order': 317,
#  'county': 318,
#  'ill': 319,
#  'remember': 320,
#  'ship': 321,
#  'away': 322,
#  'yr': 323,
#  'group': 324,
#  'refugee': 325,
#  'rescuer': 326,
#  'drought': 327,
#  'catastrophe': 328,
#  'dust': 329,
#  'twister': 330,
#  'officer': 331,
#  'shot': 332,
#  'red': 333,
#  'armageddon': 334,
#  'long': 335,
#  'friend': 336,
#  'violent': 337,
#  'white': 338,
#  'real': 339,
#  'terrorism': 340,
#  'boat': 341,
#  'cliff': 342,
#  'curfew': 343,
#  'danger': 344,
#  'stock': 345,
#  'investigator': 346,
#  'massacre': 347,
#  'mudslide': 348,
#  'structural': 349,
#  'sandstorm': 350,
#  'whirlwind': 351,
#  'tornado': 352,
#  'bring': 353,
#  'least': 354,
#  'shoot': 355,
#  'airplane': 356,
#  'wake': 357,
#  'ok': 358,
#  'national': 359,
#  'august': 360,
#  'saw': 361,
#  'x': 362,
#  'hold': 363,
#  'search': 364,
#  'tragedy': 365,
#  'effect': 366,
#  'hundred': 367,
#  'place': 368,
#  'second': 369,
#  'horrible': 370,
#  'past': 371,
#  'plane': 372,
#  'iran': 373,
#  'apocalypse': 374,
#  'mosque': 375,
#  'blast': 376,
#  'wan': 377,
#  'oh': 378,
#  'open': 379,
#  'anniversary': 380,
#  'hazard': 381,
#  'hazardous': 382,
#  'collision': 383,
#  'legionnaire': 384,
#  'devastation': 385,
#  'sunk': 386,
#  'windstorm': 387,
#  'cool': 388,
#  'begin': 389,
#  'tomorrow': 390,
#  'link': 391,
#  'stay': 392,
#  'twitter': 393,
#  'song': 394,
#  'power': 395,
#  'fedex': 396,
#  'pic': 397,
#  'ban': 398,
#  'chemical': 399,
#  'china': 400,
#  'desolation': 401,
#  'famine': 402,
#  'bang': 403,
#  'lava': 404,
#  'raze': 405,
#  'care': 406,
#  'mean': 407,
#  'talk': 408,
#  'thank': 409,
#  'hear': 410,
#  'book': 411,
#  'reunion': 412,
#  'government': 413,
#  'ebay': 414,
#  'must': 415,
#  'project': 416,
#  'id': 417,
#  'shoulder': 418,
#  'person': 419,
#  'calgary': 420,
#  'deal': 421,
#  'bioterror': 422,
#  'lady': 423,
#  'heard': 424,
#  'half': 425,
#  'traumatise': 426,
#  'catastrophic': 427,
#  'isi': 428,
#  'trouble': 429,
#  'swallow': 430,
#  'expect': 431,
#  'close': 432,
#  'street': 433,
#  'there': 434,
#  'something': 435,
#  'meltdown': 436,
#  'possible': 437,
#  'annihilate': 438,
#  'become': 439,
#  'case': 440,
#  'river': 441,
#  'zone': 442,
#  'soon': 443,
#  'bombing': 444,
#  'murderer': 445,
#  'volcano': 446,
#  'typhoon': 447,
#  'flatten': 448,
#  'hijacker': 449,
#  'reason': 450,
#  'due': 451,
#  'traffic': 452,
#  'didnt': 453,
#  'airport': 454,
#  'american': 455,
#  'medium': 456,
#  'star': 457,
#  'sure': 458,
#  'longer': 459,
#  'security': 460,
#  'pkk': 461,
#  'responder': 462,
#  'detonation': 463,
#  'tsunami': 464,
#  'pandemonium': 465,
#  'site': 466,
#  'thanks': 467,
#  'rd': 468,
#  'n': 469,
#  'men': 470,
#  'name': 471,
#  'b': 472,
#  'arson': 473,
#  'yet': 474,
#  'india': 475,
#  'music': 476,
#  'beautiful': 477,
#  'nothing': 478,
#  'level': 479,
#  'ur': 480,
#  'memory': 481,
#  'sue': 482,
#  'demolition': 483,
#  'eyewitness': 484,
#  'prebreak': 485,
#  'obliteration': 486,
#  'la': 487,
#  'three': 488,
#  'far': 489,
#  'whats': 490,
#  'side': 491,
#  'build': 492,
#  'inside': 493,
#  'block': 494,
#  'win': 495,
#  'already': 496,
#  'do': 497,
#  'believe': 498,
#  'dog': 499,
#  'horror': 500,
#  'fun': 501,
#  'share': 502,
#  'learn': 503,
#  'gun': 504,
#  'force': 505,
#  'lab': 506,
#  'policy': 507,
#  'low': 508,
#  'as': 509,
#  'cyclone': 510,
#  'abc': 511,
#  'declare': 512,
#  'hellfire': 513,
#  'upheaval': 514,
#  'ask': 515,
#  'ablaze': 516,
#  'support': 517,
#  'actually': 518,
#  'stand': 519,
#  'bc': 520,
#  'bar': 521,
#  'injure': 522,
#  'israeli': 523,
#  'team': 524,
#  'bleed': 525,
#  'large': 526,
#  'turkey': 527,
#  'bush': 528,
#  'rainstorm': 529,
#  'south': 530,
#  'north': 531,
#  'victim': 532,
#  'helicopter': 533,
#  'country': 534,
#  'hell': 535,
#  'v': 536,
#  'listen': 537,
#  'transport': 538,
#  'doesnt': 539,
#  'action': 540,
#  'yes': 541,
#  'computer': 542,
#  're\x89û': 543,
#  'line': 544,
#  'walk': 545,
#  'crew': 546,
#  'nearby': 547,
#  'mp': 548,
#  'hat': 549,
#  'seismic': 550,
#  'engulfed': 551,
#  'yearold': 552,
#  'reactor': 553,
#  'legionnaires': 554,
#  '\x89ûó': 555,
#  'month': 556,
#  'nowplaying': 557,
#  'p': 558,
#  'brown': 559,
#  'ago': 560,
#  'wont': 561,
#  'history': 562,
#  'point': 563,
#  'rule': 564,
#  'add': 565,
#  'catch': 566,
#  'anything': 567,
#  'sit': 568,
#  'burning': 569,
#  'tweet': 570,
#  'avalanche': 571,
#  'health': 572,
#  'c': 573,
#  'mark': 574,
#  'km': 575,
#  'tree': 576,
#  'islam': 577,
#  'inundate': 578,
#  'rubble': 579,
#  'snowstorm': 580,
#  'flag': 581,
#  'outside': 582,
#  'center': 583,
#  'almost': 584,
#  'aircraft': 585,
#  'maybe': 586,
#  'peace': 587,
#  'data': 588,
#  'yeah': 589,
#  'blight': 590,
#  'spot': 591,
#  'displace': 592,
#  'typhoondevastated': 593,
#  'saipan': 594,
#  'stretcher': 595,
#  'conclusively': 596,
#  'west': 597,
#  'secret': 598,
#  'k': 599,
#  'vehicle': 600,
#  'moment': 601,
#  'anyone': 602,
#  'reuters': 603,
#  'hey': 604,
#  'hand': 605,
#  'pay': 606,
#  'christian': 607,
#  'control': 608,
#  'claim': 609,
#  'lie': 610,
#  'literally': 611,
#  'bioterrorism': 612,
#  'cake': 613,
#  'rock': 614,
#  'money': 615,
#  'injured': 616,
#  'aug': 617,
#  'course': 618,
#  'knock': 619,
#  'bestnaijamade': 620,
#  'fast': 621,
#  'thousand': 622,
#  'r': 623,
#  'happy': 624,
#  'mom': 625,
#  'finally': 626,
#  'theyre': 627,
#  'might': 628,
#  'couple': 629,
#  'everything': 630,
#  'drink': 631,
#  'ball': 632,
#  'film': 633,
#  'gt': 634,
#  'track': 635,
#  'tv': 636,
#  'amid': 637,
#  'town': 638,
#  'act': 639,
#  'hollywood': 640,
#  'pretty': 641,
#  'firefighter': 642,
#  'online': 643,
#  'probably': 644,
#  'handbag': 645,
#  'coach': 646,
#  'ass': 647,
#  'village': 648,
#  'alarm': 649,
#  'camp': 650,
#  'wonder': 651,
#  'soudelor': 652,
#  'manslaughter': 653,
#  'expert': 654,
#  'shes': 655,
#  'crazy': 656,
#  'pakistan': 657,
#  'nigga': 658,
#  'annihilation': 659,
#  'human': 660,
#  'major': 661,
#  'allow': 662,
#  'class': 663,
#  'crisis': 664,
#  'date': 665,
#  'leather': 666,
#  'million': 667,
#  'okay': 668,
#  'damn': 669,
#  'youth': 670,
#  'cover': 671,
#  'space': 672,
#  'problem': 673,
#  'though': 674,
#  'giant': 675,
#  'chance': 676,
#  'desolate': 677,
#  'trench': 678,
#  'refugio': 679,
#  'costlier': 680,
#  'miner': 681,
#  'flash': 682,
#  'grow': 683,
#  'others': 684,
#  'huge': 685,
#  'america': 686,
#  'daily': 687,
#  'wrong': 688,
#  'omg': 689,
#  'cop': 690,
#  'hate': 691,
#  'total': 692,
#  'self': 693,
#  'buy': 694,
#  'escape': 695,
#  'isnt': 696,
#  'blue': 697,
#  'texas': 698,
#  'nearly': 699,
#  'seek': 700,
#  'result': 701,
#  'idea': 702,
#  'morning': 703,
#  'strike': 704,
#  'russian': 705,
#  'gbbo': 706,
#  'utc': 707,
#  'mayhem': 708,
#  'offensive': 709,
#  'heavy': 710,
#  'across': 711,
#  'haha': 712,
#  'cry': 713,
#  'sky': 714,
#  'lord': 715,
#  'hard': 716,
#  'aftershock': 717,
#  'avoid': 718,
#  'worry': 719,
#  'trust': 720,
#  'sorry': 721,
#  'usa': 722,
#  'poor': 723,
#  'radio': 724,
#  'toddler': 725,
#  'east': 726,
#  'beach': 727,
#  'militant': 728,
#  'mount': 729,
#  'view': 730,
#  'anthrax': 731,
#  'mishap': 732,
#  'cut': 733,
#  'carry': 734,
#  'test': 735,
#  'gem': 736,
#  'foot': 737,
#  'entire': 738,
#  'meek': 739,
#  'appear': 740,
#  'mph': 741,
#  'continue': 742,
#  'company': 743,
#  'angry': 744,
#  'ignition': 745,
#  'hailstorm': 746,
#  'myanmar': 747,
#  'alone': 748,
#  'arsonist': 749,
#  'climate': 750,
#  'comment': 751,
#  'member': 752,
#  'early': 753,
#  'target': 754,
#  'park': 755,
#  'number': 756,
#  'driver': 757,
#  'totally': 758,
#  'hero': 759,
#  'truth': 760,
#  'arrest': 761,
#  'green': 762,
#  'temple': 763,
#  'fukushima': 764,
#  'write': 765,
#  'create': 766,
#  'favorite': 767,
#  'public': 768,
#  'agree': 769,
#  'pain': 770,
#  'blizzard': 771,
#  'wow': 772,
#  'drake': 773,
#  'record': 774,
#  'thursday': 775,
#  'centre': 776,
#  'bbc': 777,
#  'exchange': 778,
#  'emmerdale': 779,
#  'flight': 780,
#  'quiz': 781,
#  'passenger': 782,
#  'declaration': 783,
#  'disea': 784,
#  'spring': 785,
#  'arrive': 786,
#  'front': 787,
#  'student': 788,
#  'else': 789,
#  'sleep': 790,
#  'risk': 791,
#  'travel': 792,
#  'property': 793,
#  'global': 794,
#  'ready': 795,
#  'horse': 796,
#  'soul': 797,
#  'scar': 798,
#  'till': 799,
#  'pray': 800,
#  'hire': 801,
#  'civilian': 802,
#  'germ': 803,
#  'mad': 804,
#  'party': 805,
#  'dude': 806,
#  'blew': 807,
#  'aint': 808,
#  'art': 809,
#  'investigate': 810,
#  'drop': 811,
#  'downtown': 812,
#  'insurance': 813,
#  'return': 814,
#  'instead': 815,
#  'cnn': 816,
#  'reddits': 817,
#  'virgin': 818,
#  'chile': 819,
#  'season': 820,
#  'involve': 821,
#  'scene': 822,
#  'behind': 823,
#  'four': 824,
#  'israel': 825,
#  'mention': 826,
#  'join': 827,
#  'disease': 828,
#  'question': 829,
#  'mountain': 830,
#  'bed': 831,
#  'govt': 832,
#  'prepare': 833,
#  'mop': 834,
#  'capture': 835,
#  'true': 836,
#  'theater': 837,
#  'shift': 838,
#  'gop': 839,
#  'answer': 840,
#  'king': 841,
#  'piece': 842,
#  'nd': 843,
#  'wed': 844,
#  'blown': 845,
#  'room': 846,
#  'libya': 847,
#  'nagasaki': 848,
#  'guide': 849,
#  'outrage': 850,
#  'ppl': 851,
#  'british': 852,
#  'image': 853,
#  'animal': 854,
#  'devastate': 855,
#  'download': 856,
#  'york': 857,
#  'patience': 858,
#  'former': 859,
#  'madhya': 860,
#  'pradesh': 861,
#  'cost': 862,
#  'nigerian': 863,
#  'funtenna': 864,
#  'ancient': 865,
#  'subreddits': 866,
#  'colorado': 867,
#  'london': 868,
#  'awesome': 869,
#  'upon': 870,
#  'owner': 871,
#  'dance': 872,
#  'guess': 873,
#  'kick': 874,
#  'france': 875,
#  'wednesday': 876,
#  'mode': 877,
#  'g': 878,
#  'pakistani': 879,
#  'respond': 880,
#  'match': 881,
#  'pile': 882,
#  'potus': 883,
#  'series': 884,
#  'department': 885,
#  'earth': 886,
#  'russia': 887,
#  'vote': 888,
#  'lmao': 889,
#  'muslims': 890,
#  'pamela': 891,
#  'lt': 892,
#  'young': 893,
#  'ebola': 894,
#  'threat': 895,
#  'event': 896,
#  'enough': 897,
#  'info': 898,
#  'wall': 899,
#  'meet': 900,
#  'fashion': 901,
#  'middle': 902,
#  'gunman': 903,
#  'likely': 904,
#  'brother': 905,
#  'desire': 906,
#  'press': 907,
#  'seem': 908,
#  'strong': 909,
#  'uk': 910,
#  'sea': 911,
#  'cat': 912,
#  'lamp': 913,
#  'bayelsa': 914,
#  'parole': 915,
#  'unconfirmed': 916,
#  'neighbour': 917,
#  'rly': 918,
#  'galactic': 919,
#  'direction': 920,
#  'lake': 921,
#  'ave': 922,
#  'teen': 923,
#  'mile': 924,
#  'dream': 925,
#  'include': 926,
#  'career': 927,
#  'pull': 928,
#  'safety': 929,
#  'fact': 930,
#  'review': 931,
#  'wasnt': 932,
#  'dad': 933,
#  'enjoy': 934,
#  'door': 935,
#  'sport': 936,
#  'japanese': 937,
#  'struggle': 938,
#  'palestinian': 939,
#  'ca': 940,
#  'terror': 941,
#  'warning': 942,
#  'steal': 943,
#  'geller': 944,
#  'unit': 945,
#  'album': 946,
#  'playlist': 947,
#  'occur': 948,
#  'research': 949,
#  'ahead': 950,
#  'bitch': 951,
#  'deep': 952,
#  'article': 953,
#  'super': 954,
#  'tote': 955,
#  'small': 956,
#  'washington': 957,
#  'coast': 958,
#  'ash': 959,
#  'shape': 960,
#  'parent': 961,
#  'sex': 962,
#  'freak': 963,
#  'account': 964,
#  'sad': 965,
#  'don\x89ûªt': 966,
#  'gas': 967,
#  'cable': 968,
#  'apollo': 969,
#  'map': 970,
#  'cree': 971,
#  'sick': 972,
#  'cdt': 973,
#  'aba': 974,
#  'office': 975,
#  'single': 976,
#  'pilot': 977,
#  'twelve': 978,
#  'em': 979,
#  'salt': 980,
#  'beat': 981,
#  'base': 982,
#  'funny': 983,
#  'indian': 984,
#  'crime': 985,
#  'dc': 986,
#  'remove': 987,
#  'blame': 988,
#  'court': 989,
#  'internet': 990,
#  'fly': 991,
#  'general': 992,
#  'australia': 993,
#  'list': 994,
#  'weekend': 995,
#  'e': 996,
#  'character': 997,
#  'arent': 998,
#  'matter': 999,
#  'community': 1000,
#  ...}

# %%
train_sequence = tokenizer.texts_to_sequences(train_sent)

# %%
train_sequence[0]
# Out:
# [3761, 450, 212, 80, 1337, 2423, 7]

# %%
test_sequence = tokenizer.texts_to_sequences(test_sent)

# %%
test_sequence[:5]
# Out:
# [[229, 1629, 50, 22],
#  [424, 212, 1010, 141, 392, 1712, 201],
#  [140, 3, 591, 2906, 2213, 711, 433, 107],
#  [374, 270, 6263, 92],
#  [447, 652, 17, 400, 1013]]

# %%
# Word index contains the index(numeral) assigned to every single word in our data
word_index = tokenizer.word_index
for word, num in word_index.items():
    print(f"{word} -> {num}")
    if num == 15: # words that have been assigned index 1 to 15 (index 0 is reserved)
        break
# Out:
# get -> 1
# like -> 2
# fire -> 3
# amp -> 4
# im -> 5
# go -> 6
# u -> 7
# new -> 8
# via -> 9
# one -> 10
# people -> 11
# say -> 12
# news -> 13
# bomb -> 14
# dont -> 15

# %% [markdown]
# #### Sequence Padding

# %%
from keras.preprocessing.sequence import pad_sequences

train_padded = pad_sequences(train_sequence, maxlen = max_length, padding = "post", truncating = "post")

# %%
train_padded
# Out:
# array([[3761,  450,  212, ...,    0,    0,    0],
#        [ 140,    3,  190, ...,    0,    0,    0],
#        [1470,  515, 1793, ...,    0,    0,    0],
#        ...,
#        [3515,  446, 1325, ...,    0,    0,    0],
#        [  32,  810, 2670, ...,    0,    0,    0],
#        [ 128,   33,  405, ...,    0,    0,    0]], dtype=int32)

# %%
test_padded = pad_sequences(test_sequence, maxlen = max_length, padding = "post", truncating = "post")

# %%
test_padded
# Out:
# array([[ 229, 1629,   50, ...,    0,    0,    0],
#        [ 424,  212, 1010, ...,    0,    0,    0],
#        [ 140,    3,  591, ...,    0,    0,    0],
#        ...,
#        [ 762,  544,  296, ...,    0,    0,    0],
#        [5134,  170,  382, ...,    0,    0,    0],
#        [4871, 2019, 1326, ...,    0,    0,    0]], dtype=int32)

# %% [markdown]
# ### Model Building using LSTM

# %%
from keras.models import Sequential
from keras.layers import Embedding, LSTM, Dense, Dropout
from keras.initializers import Constant
from keras.optimizers import Adam
import tensorflow as tf

def leaky_relu(z, name = None):
    return tf.maximum(0.01*z,z, name = name)

model = Sequential()

model.add(Embedding(words,32,input_length = max_length)) # embedding layer
model.add(LSTM(64, dropout = 0.1)) # RNN layer
model.add(Dense(units = 32 , activation = leaky_relu)) # Dense layer with leaky_relu activation
model.add(Dense(1, activation = tf.nn.elu))

optimizer = Adam(learning_rate = 3e-4)

model.compile(loss = 'binary_crossentropy', optimizer = optimizer, metrics = ['accuracy'])

# %%
# Looking at the structure of the network
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# embedding (Embedding)        (None, 20, 32)            630208
# _________________________________________________________________
# lstm (LSTM)                  (None, 64)                24832
# _________________________________________________________________
# dense (Dense)                (None, 32)                2080
# _________________________________________________________________
# dense_1 (Dense)              (None, 1)                 33
# =================================================================
# Total params: 657,153
# Trainable params: 657,153
# Non-trainable params: 0
# _________________________________________________________________

# %%
# training the model over 40 iterations
model.fit(train_padded, train_labels, epochs = 40)
# Out:
# Epoch 1/40
# 238/238 [==============================] - 5s 21ms/step - loss: 0.9361 - accuracy: 0.5808
# Epoch 2/40
# 238/238 [==============================] - 4s 18ms/step - loss: 0.5031 - accuracy: 0.7721
# Epoch 3/40
# 238/238 [==============================] - 4s 18ms/step - loss: 0.3578 - accuracy: 0.8542
# Epoch 4/40
# 238/238 [==============================] - 4s 18ms/step - loss: 0.3105 - accuracy: 0.8931
# Epoch 5/40
# 238/238 [==============================] - 4s 19ms/step - loss: 0.2906 - accuracy: 0.9224
# Epoch 6/40
# 238/238 [==============================] - 4s 18ms/step - loss: 0.2048 - accuracy: 0.9393
# Epoch 7/40
# 238/238 [==============================] - 5s 20ms/step - loss: 0.1620 - accuracy: 0.9582
# Epoch 8/40
# 238/238 [==============================] - 4s 19ms/step - loss: 0.1275 - accuracy: 0.9701
# Epoch 9/40
# 238/238 [==============================] - 4s 18ms/step - loss: 0.1113 - accuracy: 0.9794
# Epoch 10/40
# 238/238 [==============================] - 4s 18ms/step - loss: 0.4988 - accuracy: 0.9371
# Epoch 11/40
# 238/238 [==============================] - 4s 18ms/step - loss: 0.1049 - accuracy: 0.9836
# Epoch 12/40
# 238/238 [==============================] - 4s 19ms/step - loss: 0.1016 - accuracy: 0.9845
# Epoch 13/40
# 238/238 [==============================] - 4s 18ms/step - loss: 0.0846 - accuracy: 0.9869
# Epoch 14/40
# 238/238 [==============================] - 4s 18ms/step - loss: 0.0730 - accuracy: 0.9874
# Epoch 15/40
# 238/238 [==============================] - 4s 19ms/step - loss: 0.0663 - accuracy: 0.9888
# Epoch 16/40
# 238/238 [==============================] - 4s 18ms/step - loss: 0.0630 - accuracy: 0.9900
# Epoch 17/40
# 238/238 [==============================] - 4s 18ms/step - loss: 0.0629 - accuracy: 0.9915
# Epoch 18/40
# 238/238 [==============================] - 4s 18ms/step - loss: 0.0617 - accuracy: 0.9915
# Epoch 19/40
# 238/238 [==============================] - 5s 19ms/step - loss: 0.0633 - accuracy: 0.9911
# Epoch 20/40
# 238/238 [==============================] - 5s 21ms/step - loss: 0.0653 - accuracy: 0.9912
# Epoch 21/40
# 238/238 [==============================] - 5s 21ms/step - loss: 0.0601 - accuracy: 0.9917
# Epoch 22/40
# 238/238 [==============================] - 4s 19ms/step - loss: 0.0588 - accuracy: 0.9916
# Epoch 23/40
# 238/238 [==============================] - 4s 18ms/step - loss: 0.0614 - accuracy: 0.9921
# Epoch 24/40
# 238/238 [==============================] - 4s 18ms/step - loss: 0.0774 - accuracy: 0.9886
# Epoch 25/40
# 238/238 [==============================] - 4s 19ms/step - loss: 0.0759 - accuracy: 0.9888
# Epoch 26/40
# 238/238 [==============================] - 5s 19ms/step - loss: 0.0722 - accuracy: 0.9920
# Epoch 27/40
# 238/238 [==============================] - 5s 19ms/step - loss: 0.0676 - accuracy: 0.9929
# Epoch 28/40
# 238/238 [==============================] - 4s 19ms/step - loss: 0.0698 - accuracy: 0.9926
# Epoch 29/40
# 238/238 [==============================] - 4s 19ms/step - loss: 0.0724 - accuracy: 0.9924
# Epoch 30/40
# 238/238 [==============================] - 4s 19ms/step - loss: 0.0691 - accuracy: 0.9926
# Epoch 31/40
# 238/238 [==============================] - 4s 19ms/step - loss: 0.1115 - accuracy: 0.9811
# Epoch 32/40
# 238/238 [==============================] - 4s 19ms/step - loss: 0.0797 - accuracy: 0.9913
# Epoch 33/40
# 238/238 [==============================] - 5s 20ms/step - loss: 0.0591 - accuracy: 0.9928
# Epoch 34/40
# 238/238 [==============================] - 5s 20ms/step - loss: 0.0559 - accuracy: 0.9928
# Epoch 35/40
# 238/238 [==============================] - 5s 19ms/step - loss: 0.0556 - accuracy: 0.9923
# Epoch 36/40
# 238/238 [==============================] - 5s 19ms/step - loss: 0.0543 - accuracy: 0.9932
# Epoch 37/40
# 238/238 [==============================] - 5s 19ms/step - loss: 0.0549 - accuracy: 0.9928
# Epoch 38/40
# 238/238 [==============================] - 4s 19ms/step - loss: 0.0586 - accuracy: 0.9924
# Epoch 39/40
# 238/238 [==============================] - 5s 19ms/step - loss: 0.0557 - accuracy: 0.9930
# Epoch 40/40
# 238/238 [==============================] - 5s 19ms/step - loss: 0.0550 - accuracy: 0.9923

# %%
import h5py
#model.save('baseline_lstm_model.h5')

# %%
from keras.models import load_model
#model = load_model('baseline_lstm_model.h5')

# %%
lstm_base_pred = model.predict_classes(test_padded, verbose = 0)

# %%
lstm_base_pred = lstm_base_pred.reshape(-1,1).ravel()

# %%
Prediction_results_lstm = pd.DataFrame({"target":lstm_base_pred}, index = test_id)
Prediction_results_lstm
# Out:
#        target
# id
# 0           0
# 2           1
# 3           1
# 9           1
# 11          1
# ...       ...
# 10861       1
# 10865       1
# 10868       1
# 10874       1
# 10875       1
#
# [3263 rows x 1 columns]

# %%
#submission_lstm_elu_leaky_relu = Prediction_results_lstm.to_csv('submission_lstm_elu_leaky_relu.csv')
